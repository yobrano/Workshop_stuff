# %% [markdown]
# <font color="blue">To use this notebook on Colaboratory, you will need to make a copy of it. Go to File > Save a Copy in Drive. You can then use the new copy that will appear in the new tab.</font>

# %% [markdown]
# # Practice Notebook: Data Analysis with Python

# %% [markdown]
# ## Pre-requisites

# %%
# Pre-requisite 1
# ---
# Importing pandas library for data manipulation
# ---
# OUR CODE GOES BELOW
#
import pandas as pd

# %%
# Pre-requisite 2
# ---
# Importing numpy library for scientific computations
# ---
# OUR CODE GOES BELOW
#
import numpy as np

# %% [markdown]
# ## 1. Data Exploration

# %% [markdown]
# ### Examples

# %%
# Viewing top records of the dataset
# ---
# You have been given the following dataset on Ebola cases.
# Let's preview the first 10 rows.
# ---
# Dataset url = https://bit.ly/2T60DKG
#
ebola_df = pd.read_csv('https://bit.ly/2T60DKG')
ebola_df.head(10)
# Out:
#   Country  Month  Year   Lat  Lon   Value
# 0  Guinea      3    14  9.95 -9.7   122.0
# 1  Guinea      4    14  9.95 -9.7   224.0
# 2  Guinea      5    14  9.95 -9.7   291.0
# 3  Guinea      6    14  9.95 -9.7   413.0
# 4  Guinea      7    14  9.95 -9.7   460.0
# 5  Guinea      8    14  9.95 -9.7   771.0
# 6  Guinea      9    14  9.95 -9.7  1022.0
# 7  Guinea     10    14  9.95 -9.7     NaN
# 8  Guinea     11    14  9.95 -9.7     NaN
# 9  Guinea     12    14  9.95 -9.7     NaN

# %%
# Viewing last records of the dataset
# ---
# Preview the last 10 records of the ebola dataset
# ---

last_ebola_df = ebola_df.tail(10)
last_ebola_df
# Out:
#          Country  Month  Year    Lat    Lon   Value
# 21       Senegal      8    14  14.50 -14.45     1.0
# 22       Senegal      9    14  14.50 -14.45     3.0
# 23  Sierra Leone      5    14   8.46 -11.78    50.0
# 24  Sierra Leone      6    14   8.46 -11.78   239.0
# 25  Sierra Leone      7    14   8.46 -11.78   533.0
# 26  Sierra Leone      8    14   8.46 -11.78  1216.0
# 27  Sierra Leone      9    14   8.46 -11.78  1940.0
# 28  Sierra Leone     10    14   8.46 -11.78     NaN
# 29  Sierra Leone     11    14   8.46 -11.78     NaN
# 30  Sierra Leone     12    14   8.46 -11.78     NaN

# %%
# Taking a sample
# ---
# Take a sample of the 5 records from the ebola dataset
# ---
#
sample_ebola_df = ebola_df.sample(5)
sample_ebola_df
# Out:
#          Country  Month  Year    Lat    Lon  Value
# 23  Sierra Leone      5    14   8.46 -11.78   50.0
# 17       Liberia     11    14   6.43  -9.43    NaN
# 22       Senegal      9    14  14.50 -14.45    3.0
# 12       Liberia      6    14   6.43  -9.43  107.0
# 7         Guinea     10    14   9.95  -9.70    NaN

# %% [markdown]
# ### <font color="green">Challenges</font>

# %%
# Challenge 1
# ---
# View the first 20 records of the given banknotes dataset
# ---
# Dataset url = https://bit.ly/2yT9oAU
# ---
# OUR CODE GOES BELOW
#
url = "https://bit.ly/2yT9oAU"
banknotes_df = pd.read_csv(url)
banknotes_df.head(20)
# Out:
#     conterfeit  Length   Left  Right  Bottom   Top  Diagonal
# 0            0   214.8  131.0  131.1     9.0   9.7     141.0
# 1            0   214.6  129.7  129.7     8.1   9.5     141.7
# 2            0   214.8  129.7  129.7     8.7   9.6     142.2
# 3            0   214.8  129.7  129.6     7.5  10.4     142.0
# 4            0   215.0  129.6  129.7    10.4   7.7     141.8
# 5            0   215.7  130.8  130.5     9.0  10.1     141.4
# 6            0   215.5  129.5  129.7     7.9   9.6     141.6
# 7            0   214.5  129.6  129.2     7.2  10.7     141.7
# 8            0   214.9  129.4  129.7     8.2  11.0     141.9
# 9            0   215.2  130.4  130.3     9.2  10.0     140.7
# 10           0   215.3  130.4  130.3     7.9  11.7     141.8
# 11           0   215.1  129.5  129.6     7.7  10.5     142.2
# 12           0   215.2  130.8  129.6     7.9  10.8     141.4
# 13           0   214.7  129.7  129.7     7.7  10.9     141.7
# 14           0   215.1  129.9  129.7     7.7  10.8     141.8
# 15           0   214.5  129.8  129.8     9.3   8.5     141.6
# 16           0   214.6  129.9  130.1     8.2   9.8     141.7
# 17           0   215.0  129.9  129.7     9.0   9.0     141.9
# 18           0   215.2  129.6  129.6     7.4  11.5     141.5
# 19           0   214.7  130.2  129.9     8.6  10.0     141.9

# %%
# Challenge 2
# ---
# View the last 5 records of the above banknotes dataset
# ---
# OUR CODE GOES BELOW
#
banknotes_df.tail(5)
# Out:
#      conterfeit  Length   Left  Right  Bottom   Top  Diagonal
# 195           1   215.0  130.4  130.3     9.9  12.1     139.6
# 196           1   215.1  130.3  129.9    10.3  11.5     139.7
# 197           1   214.8  130.3  130.4    10.6  11.1     140.0
# 198           1   214.7  130.7  130.8    11.2  11.2     139.4
# 199           1   214.3  129.9  129.9    10.2  11.5     139.6

# %%
# Challenge 3
# ---
# Get a sample of 50 records from the above banknotes dataset
# ---
# OUR CODE GOES BELOW
#

banknotes_df.sample(50)
# Out:
#      conterfeit  Length   Left  Right  Bottom   Top  Diagonal
# 34            0   215.9  130.4  130.0     8.9  10.6     141.4
# 50            0   214.6  129.8  129.4     7.2  10.0     141.3
# 28            0   215.1  130.0  130.0     7.4  10.5     141.8
# 163           1   214.7  130.1  130.2    11.6  10.9     139.1
# 147           1   215.3  130.6  130.3     9.3  11.3     138.1
# 19            0   214.7  130.2  129.9     8.6  10.0     141.9
# 159           1   214.6  130.6  130.1     8.1  12.1     137.9
# 178           1   214.8  130.5  130.3    10.2  12.1     139.1
# 90            0   214.7  129.7  129.3     8.6   9.6     141.6
# 69            0   214.9  130.2  130.2     8.0  11.2     139.6
# 128           1   215.1  130.2  130.2    10.1  11.3     140.3
# 139           1   214.5  130.5  130.2    11.8  10.2     139.6
# 18            0   215.2  129.6  129.6     7.4  11.5     141.5
# 14            0   215.1  129.9  129.7     7.7  10.8     141.8
# 76            0   214.9  129.9  130.1     8.8  10.0     141.2
# 60            0   215.1  129.6  129.3     8.3   9.9     141.6
# 177           1   214.5  130.4  130.0     9.9  12.0     139.6
# 122           1   215.3  130.8  131.1    11.6  10.6     140.2
# 106           1   215.3  130.3  130.1     9.3  12.1     140.2
# 81            0   214.9  129.8  129.6     7.5  10.3     141.0
# 161           1   214.9  130.5  130.1     9.9  10.2     138.1
# 143           1   215.0  130.5  130.4    10.6  11.1     139.9
# 73            0   214.4  129.9  129.6     7.5  10.5     141.8
# 96            0   215.0  130.4  130.3     9.1  10.2     141.1
# 123           1   215.1  130.7  130.4    10.5  11.2     139.7
# 124           1   214.7  130.5  130.5     9.9  10.3     140.1
# 40            0   214.4  129.8  129.2     8.9   9.4     142.3
# 162           1   214.6  130.1  130.0    11.5  10.6     139.5
# 29            0   214.8  129.7  129.3     8.3   9.0     142.0
# 33            0   215.6  130.4  130.1     8.4  10.3     141.0
# 175           1   214.9  130.4  130.2    11.9  10.7     139.0
# 172           1   214.8  130.5  130.3    11.8  10.5     139.4
# 136           1   214.6  129.8  130.2    10.7  11.1     139.4
# 197           1   214.8  130.3  130.4    10.6  11.1     140.0
# 12            0   215.2  130.8  129.6     7.9  10.8     141.4
# 63            0   214.5  130.0  129.5     8.0  10.8     141.4
# 13            0   214.7  129.7  129.7     7.7  10.9     141.7
# 141           1   214.7  130.0  129.4    10.2  11.0     139.2
# 87            0   215.0  129.6  129.2     8.4  10.2     142.1
# 64            0   215.0  130.0  129.8     8.6  10.6     141.5
# 10            0   215.3  130.4  130.3     7.9  11.7     141.8
# 188           1   214.8  129.9  130.2     9.6  11.9     139.4
# 98            0   215.1  130.0  129.8     9.1  10.2     141.5
# 54            0   214.5  129.4  129.5     7.9  10.0     141.4
# 100           1   214.4  130.1  130.3     9.7  11.7     139.8
# 105           1   215.0  130.2  130.2    10.6  10.7     139.9
# 15            0   214.5  129.8  129.8     9.3   8.5     141.6
# 78            0   215.2  130.5  129.8     7.9  10.9     140.9
# 160           1   215.6  130.1  129.7     7.4  12.2     138.4
# 112           1   215.4  130.7  131.1     9.7  11.8     140.6

# %% [markdown]
# ## 2. Selecting Columns I

# %% [markdown]
# ### Examples

# %%
# Selecting a Column
# ---
# Select the first 5 values of the Value column from the previously used ebola dataset
# ---
#
ebola_df_value = ebola_df[['Value']]
ebola_df_value.head()
# Out:
#    Value
# 0  122.0
# 1  224.0
# 2  291.0
# 3  413.0
# 4  460.0

# %%
# Selecting Multiple Columns I
# ---
# Select last 5 records from Country and Latitude column i.e. Lat, of the ebola dataset
# ---
#
# ebola_df_country_lat = ebola_df[['Country', 'Lat']]
# ebola_df_country_lat.tail()

# Method 2
# Uncomment the following lines
# ---
ebola_df_country_lat_method2 = ebola_df.iloc[:,[0, 3]]
ebola_df_country_lat_method2.tail()
# Out:
#          Country   Lat
# 26  Sierra Leone  8.46
# 27  Sierra Leone  8.46
# 28  Sierra Leone  8.46
# 29  Sierra Leone  8.46
# 30  Sierra Leone  8.46

# %%
# Selecting Multiple Columns II
# ---
# Select last 5 records of the first 2 columns of the the ebola dataset
# ---
#
ebola_df_country_bonus = ebola_df.iloc[:,0:2]
ebola_df_country_bonus.tail()
# Out:
#          Country  Month
# 26  Sierra Leone      8
# 27  Sierra Leone      9
# 28  Sierra Leone     10
# 29  Sierra Leone     11
# 30  Sierra Leone     12

# %% [markdown]
# ### <font color="green">Challenges</font>

# %%
# Challenge 1
# ---
# Select the first 20 records of the Diagonal column in the given banknotes dataset.
# ---
# Dataset url = https://bit.ly/2yT9oAU
# ---
# OUR CODE GOES BELOW
#
bn_diagonals_df = banknotes_df["Diagonal"]
bn_diagonals_df.head(20)
# Out:
# 0     141.0
# 1     141.7
# 2     142.2
# 3     142.0
# 4     141.8
# 5     141.4
# 6     141.6
# 7     141.7
# 8     141.9
# 9     140.7
# 10    141.8
# 11    142.2
# 12    141.4
# 13    141.7
# 14    141.8
# 15    141.6
# 16    141.7
# 17    141.9
# 18    141.5
# 19    141.9
# Name: Diagonal, dtype: float64

# %%
# Challenge 2
# ---
# Select a sample of 10 records from the Diagonal and conterfeit column using the banknotes dataset.
# ---
# OUR CODE GOES BELOW
#
banknotes_df[["conterfeit", "Diagonal"]].sample(10)
# Out:
#      conterfeit  Diagonal
# 154           1     139.5
# 186           1     138.5
# 192           1     139.2
# 127           1     140.0
# 85            0     141.5
# 105           1     139.9
# 33            0     141.0
# 46            0     141.5
# 31            0     142.3
# 190           1     139.4

# %%
# Challenge 3
# ---
# In prepartion for data modeling, you're required to select last 5 colums of the banknotes dataset.
# Once you do so, preview the dataframe to check whether you've selected the columns correctly.
# ---
# OUR CODE GOES BELOW
#

banknotes_df.iloc[:,-5:]
# Out:
#       Left  Right  Bottom   Top  Diagonal
# 0    131.0  131.1     9.0   9.7     141.0
# 1    129.7  129.7     8.1   9.5     141.7
# 2    129.7  129.7     8.7   9.6     142.2
# 3    129.7  129.6     7.5  10.4     142.0
# 4    129.6  129.7    10.4   7.7     141.8
# ..     ...    ...     ...   ...       ...
# 195  130.4  130.3     9.9  12.1     139.6
# 196  130.3  129.9    10.3  11.5     139.7
# 197  130.3  130.4    10.6  11.1     140.0
# 198  130.7  130.8    11.2  11.2     139.4
# 199  129.9  129.9    10.2  11.5     139.6
#
# [200 rows x 5 columns]

# %% [markdown]
# ## 3. Selecting Columns II

# %% [markdown]
# ### Examples

# %%
# Selecting Unique Values in a column
# ---
# Let's select unique values from the Country column in the ebola dataset
# ---
#
ebola_countries = ebola_df['Country'].unique()

# We use the list() method to get a list else
# we would get an array.
# ---
#
list(ebola_countries)
ebola_df
# Out:
#          Country  Month  Year    Lat    Lon   Value
# 0         Guinea      3    14   9.95  -9.70   122.0
# 1         Guinea      4    14   9.95  -9.70   224.0
# 2         Guinea      5    14   9.95  -9.70   291.0
# 3         Guinea      6    14   9.95  -9.70   413.0
# 4         Guinea      7    14   9.95  -9.70   460.0
# 5         Guinea      8    14   9.95  -9.70   771.0
# 6         Guinea      9    14   9.95  -9.70  1022.0
# 7         Guinea     10    14   9.95  -9.70     NaN
# 8         Guinea     11    14   9.95  -9.70     NaN
# 9         Guinea     12    14   9.95  -9.70     NaN
# 10       Liberia      4    14   6.43  -9.43    35.0
# 11       Liberia      5    14   6.43  -9.43    13.0
# 12       Liberia      6    14   6.43  -9.43   107.0
# 13       Liberia      7    14   6.43  -9.43   329.0
# 14       Liberia      8    14   6.43  -9.43  1395.0
# 15       Liberia      9    14   6.43  -9.43  3362.0
# 16       Liberia     10    14   6.43  -9.43     NaN
# 17       Liberia     11    14   6.43  -9.43     NaN
# 18       Liberia     12    14   6.43  -9.43     NaN
# 19          Mali     10    14  17.57  -4.00     1.0
# 20          Mali     11    14  17.57  -4.00     8.0
# 21       Senegal      8    14  14.50 -14.45     1.0
# 22       Senegal      9    14  14.50 -14.45     3.0
# 23  Sierra Leone      5    14   8.46 -11.78    50.0
# 24  Sierra Leone      6    14   8.46 -11.78   239.0
# 25  Sierra Leone      7    14   8.46 -11.78   533.0
# 26  Sierra Leone      8    14   8.46 -11.78  1216.0
# 27  Sierra Leone      9    14   8.46 -11.78  1940.0
# 28  Sierra Leone     10    14   8.46 -11.78     NaN
# 29  Sierra Leone     11    14   8.46 -11.78     NaN
# 30  Sierra Leone     12    14   8.46 -11.78     NaN

# %%
# Selecting Rows with Columns with certain values
# ---
# We will select all Liberia records
#
liberia_records = ebola_df[ebola_df.Country.isin(['Liberia'])]
liberia_records
# Out:
#     Country  Month  Year   Lat   Lon   Value
# 10  Liberia      4    14  6.43 -9.43    35.0
# 11  Liberia      5    14  6.43 -9.43    13.0
# 12  Liberia      6    14  6.43 -9.43   107.0
# 13  Liberia      7    14  6.43 -9.43   329.0
# 14  Liberia      8    14  6.43 -9.43  1395.0
# 15  Liberia      9    14  6.43 -9.43  3362.0
# 16  Liberia     10    14  6.43 -9.43     NaN
# 17  Liberia     11    14  6.43 -9.43     NaN
# 18  Liberia     12    14  6.43 -9.43     NaN

# %%
# Selecting Records with Columns without certain values
# ---
# We will select all other records apart from the Liberia ones.
# Let's confirm our result by checking a sample of 10 records.
# ---
#
other_country_records = ebola_df[~ebola_df.Country.isin(['Liberia'])]
other_country_records.sample(15)
# Out:
#          Country  Month  Year    Lat    Lon   Value
# 26  Sierra Leone      8    14   8.46 -11.78  1216.0
# 9         Guinea     12    14   9.95  -9.70     NaN
# 1         Guinea      4    14   9.95  -9.70   224.0
# 4         Guinea      7    14   9.95  -9.70   460.0
# 23  Sierra Leone      5    14   8.46 -11.78    50.0
# 8         Guinea     11    14   9.95  -9.70     NaN
# 25  Sierra Leone      7    14   8.46 -11.78   533.0
# 0         Guinea      3    14   9.95  -9.70   122.0
# 20          Mali     11    14  17.57  -4.00     8.0
# 3         Guinea      6    14   9.95  -9.70   413.0
# 7         Guinea     10    14   9.95  -9.70     NaN
# 19          Mali     10    14  17.57  -4.00     1.0
# 5         Guinea      8    14   9.95  -9.70   771.0
# 6         Guinea      9    14   9.95  -9.70  1022.0
# 21       Senegal      8    14  14.50 -14.45     1.0

# %% [markdown]
# ### <font color="green">Challenges</font>

# %%
# Challenge 1
# ---
# Select and preview the most similar banknotes length measurements?
# ---
# Dataset url = https://bit.ly/2yT9oAU
# ---
#

list(banknotes_df["Length"].unique())
# Out:
# [214.8,
#  214.6,
#  215.0,
#  215.7,
#  215.5,
#  214.5,
#  214.9,
#  215.2,
#  215.3,
#  215.1,
#  214.7,
#  215.6,
#  215.9,
#  213.9,
#  214.4,
#  214.3,
#  215.4,
#  213.8,
#  214.1,
#  214.2,
#  216.3]

# %%
# Challenge 2
# ---
# Select and preview the least similar banknotes diagonal measurements?
# ---
#
list(banknotes_df["Diagonal"].unique())
# Out:
# [141.0,
#  141.7,
#  142.2,
#  142.0,
#  141.8,
#  141.4,
#  141.6,
#  141.9,
#  140.7,
#  141.5,
#  141.1,
#  142.3,
#  142.4,
#  142.1,
#  141.3,
#  140.9,
#  141.2,
#  140.8,
#  139.6,
#  140.6,
#  139.8,
#  139.5,
#  140.2,
#  140.3,
#  139.7,
#  139.9,
#  139.4,
#  139.2,
#  140.1,
#  140.0,
#  138.3,
#  139.3,
#  138.1,
#  139.0,
#  137.9,
#  138.4,
#  139.1,
#  138.8,
#  138.6,
#  137.8,
#  138.7,
#  138.5]

# %%
# Challenge 3
# ---
# How many banknotes had a left measurement and right measurement greater than 129?
# Get a sample of the records and later determine the no.
# Hint: Sample  Use len() to determine the no. of items.
# ---
#

banknotes_sample = banknotes_df[banknotes_df["Left"] > 129].sample(20)
len(banknotes_df[banknotes_df["Left"] > 129]) # notes with left > 129
# Out:
# 199

# %% [markdown]
# ## 4. Ranking / Sorting

# %% [markdown]
# ### Examples

# %%
# Sorting in Ascending / Descending Order
# ---
# From the ebola dataset sort the Guinea records in descending order
# ---
# OUR CODE GOES BELOW
#
guinea_records = ebola_df[ebola_df.Country.isin(['Guinea'])].sort_values(by='Value', ascending=1)
guinea_records.head()
# Out:
#   Country  Month  Year   Lat  Lon  Value
# 0  Guinea      3    14  9.95 -9.7  122.0
# 1  Guinea      4    14  9.95 -9.7  224.0
# 2  Guinea      5    14  9.95 -9.7  291.0
# 3  Guinea      6    14  9.95 -9.7  413.0
# 4  Guinea      7    14  9.95 -9.7  460.0

# %%
# Ranking in Ascending Order
# ---
# Create a new column that is the rank of the value of 'Value' in descending order
# ---
#
ebola_df['Ranking'] = ebola_df['Value'].rank(ascending=0)
ebola_df.head()
# Out:
#   Country  Month  Year   Lat  Lon  Value  Ranking
# 0  Guinea      3    14  9.95 -9.7  122.0     14.0
# 1  Guinea      4    14  9.95 -9.7  224.0     13.0
# 2  Guinea      5    14  9.95 -9.7  291.0     11.0
# 3  Guinea      6    14  9.95 -9.7  413.0      9.0
# 4  Guinea      7    14  9.95 -9.7  460.0      8.0

# %% [markdown]
# ### <font color="green">Challenges</font>

# %%
# Challenge 1
# ---
# From the ebola dataset, select the Mali records with more
# than 100 cases and sort them in descending order.
# ---
#

ebola_df[ebola_df.Country.isin(["Mali"])]
# ebola_df.Country.isin(["Mali"])
# Out:
#    Country  Month  Year    Lat  Lon  Value  Ranking
# 19    Mali     10    14  17.57 -4.0    1.0     21.5
# 20    Mali     11    14  17.57 -4.0    8.0     19.0

# %%
# Challenge 2
# ---
# From the banknotes dataset, find out which records had the largest
# diagonal length? In addition, rank them by left size.
# ---
# Dataset url = https://bit.ly/2yT9oAU
# ---
#

max_diagonal = banknotes_df["Diagonal"].max()
max_diagonal_note = banknotes_df[banknotes_df["Diagonal"] == max_diagonal].copy()
max_diagonal_note["Left Ranking"] = max_diagonal_note["Left"].rank()

max_diagonal_note
# Out:
#     conterfeit  Length   Left  Right  Bottom  Top  Diagonal  Left Ranking
# 26           0   215.5  130.2  130.1     8.9  9.8     142.4           1.0

# %% [markdown]
# ## 5. Aggregate Functions

# %% [markdown]
# ### Examples

# %%
# Example 1
# ---
# Shape
# ---
# How many Liberian records do we have in our ebola dataset?
# ---
# (records, columns)
#
liberia_records = ebola_df[ebola_df.Country.isin(['Liberia'])]
liberia_records.shape

# (9 records, 7 columns)
# Out:
# (9, 7)

# %%
# Example 2
# ---
# Count() Function
# ---
# How many values do we have across our variables in our ebola dataset?
# ---
#
liberia_records = ebola_df[ebola_df.Country.isin(['Liberia'])]
liberia_records.count()
# Out:
# Country    9
# Month      9
# Year       9
# Lat        9
# Lon        9
# Value      6
# Ranking    6
# dtype: int64

# %%
# Example 3
# ---
# Unique Occurrences
# ---
# Were all records in our ebola dataset unique?
# ---
#
ebola_df[ebola_df.duplicated()].shape

# Yes, there were no duplicate records
# Out:
# (0, 7)

# %%
# Example 4
# ---
# Sum
# ---
# How many ebola cases in Sierra Leone were reported given the ebola dataset?
# ---
#
sierra_cases_sum = ebola_df[ebola_df.Country.isin(['Sierra Leone'])][['Value']].sum()
sierra_cases_sum
# Out:
# Value    3978.0
# dtype: float64

# %%
# Example 5
# ---
# Minimum
# ---
# What was the minimum number of ebola cases?
# ---
#
least_cases = ebola_df.Value.min()
least_cases
# Out:
# 1.0

# %%
# Maximum
# ---
# What was the maximum number of ebola cases?
# ---
#
highest_cases = ebola_df.Value.max()
highest_cases
# Out:
# 3362.0

# %%
# Mean
# ---
# What was the average number of ebola cases in Sierra Leone?
# ---
#
sierra_cases_avg = ebola_df[ebola_df.Country.isin(['Sierra Leone'])][['Value']].mean()
sierra_cases_avg
# Out:
# Value    795.6
# dtype: float64

# %%
# Mode
# ---
# What was the most frequent value in the Ebola dataset?
# ---
#

frequent_values_df = ebola_df['Country'].mode()
frequent_values_df
# Out:
# 0    Guinea
# Name: Country, dtype: object

# %%
# Median
# ---
# The median value of the Ebola cases.
# ---
#
median_values_df = ebola_df['Value'].median()
median_values_df
# Out:
# 265.0

# %%
# Summary Statistics
# ---
# Create a descriptive statistics table of the given ebola dataset
# in preparation for further analysis.
# ---
#
ebola_df.describe()
# Out:
#           Month  Year        Lat        Lon        Value    Ranking
# count  31.00000  31.0  31.000000  31.000000    22.000000  22.000000
# mean    8.16129  14.0   9.328710 -10.097097   569.772727  11.500000
# std     2.59611   0.0   3.026781   2.163978   816.056950   6.491753
# min     3.00000  14.0   6.430000 -14.450000     1.000000   1.000000
# 25%     6.00000  14.0   6.430000 -11.780000    38.750000   6.250000
# 50%     8.00000  14.0   8.460000  -9.700000   265.000000  11.500000
# 75%    10.00000  14.0   9.950000  -9.430000   711.500000  16.750000
# max    12.00000  14.0  17.570000  -4.000000  3362.000000  21.500000

# %% [markdown]
# ### <font color="green">Challenges</font>

# %%
# Challenge 1
# ---
# How many records can be found in the following insurance dataset?
# ---
# Insurance Dataset url = https://bit.ly/2y5CRYc
# ---
# This dataset contains anonymised patient data.
# ---
# OUR CODE GOES BELOW
#

url = "https://bit.ly/2y5CRYc"
insurance_df = pd.read_csv(url)
insurance_df.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
# Challenge 2
# ---
# Are there any duplicates in the insurance dataset?
# ---
# OUR CODE GOES BELOW
#

has_duplicates = insurance_df.duplicated().sum() > 0
has_duplicates
# Out:
# True

# %%
# Challenge 3
# ---
# Which regions did the patients come from?
# ---
# OUR CODE GOES BELOW
#

regions = list(insurance_df["region"].unique())
regions
# Out:
# ['southwest', 'southeast', 'northwest', 'northeast']

# %%
# Challenge 4
# ---
# What was the highest bmi recorded for patients from northwest and southwest regions?
# ---
# OUR CODE GOES BELOW
#
northwest= insurance_df[insurance_df["region"] == "northwest"]
northwest_max_bmi = northwest[northwest["bmi"] == northwest["bmi"].max()]
northwest_max_bmi

southwest= insurance_df[insurance_df["region"] == "southwest"]
southwest_max_bmi = southwest[southwest["bmi"] == southwest["bmi"].max()]
southwest_max_bmi

pd.concat([southwest_max_bmi, northwest_max_bmi])

# Alternatively
insurance_df.groupby("region")["bmi"].max()[["northwest", "southwest"]]
# Out:
# region
# northwest    42.9
# southwest    47.6
# Name: bmi, dtype: float64

# %%
# Challenge 5
# ---
# What was the youngest age of a patient?
# ---
# OUR CODE GOES BELOW
#

min_age = insurance_df["age"].min()
min_age
# Out:
# 18

# %%
# Challenge 6
# ---
# What was the average bmi recorded for patients above 50 years old?
# ---
# OUR CODE GOES BELOW
#

mean_gt_50 = insurance_df[insurance_df["age"] > 50]["age"].mean()
mean_gt_50
# Out:
# 57.140449438202246

# %%
# Challenge 7
# ---
# How much was spent collectively by male and female patients?
# ---
# OUR CODE GOES BELOW
#
gender_total_expences = {
    "male": insurance_df[insurance_df["sex"] == "male"]["expenses"].sum(),
    "female": insurance_df[insurance_df["sex"] == "female"]["expenses"].sum()
}
gender_total_expences

# Alternatively
insurance_df.groupby("sex")["expenses"].sum()
# Out:
# sex
# female    8321061.23
# male      9434763.96
# Name: expenses, dtype: float64

# %% [markdown]
# ## 6. Grouping

# %% [markdown]
# ### Examples

# %%
# Let's first load and preview the dataset that we will need for our examples
# ---
#
insurance_df = pd.read_csv('https://bit.ly/2y5CRYc')
insurance_df.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
# Example 1
# ---
# The groupby() function is used to split the data into groups based on some criteria.
# ---
# We will start by grouping by a single column and including an aggregate function as shown.
# ---
# NB: We will not store any our dataframe in a variable for ease of
# performing computations
# ---
#
insurance_df.groupby('region')

# %%
# Example 2
# ---
# We can get the first entry for each gender by doing the following
# ---
# NB: You can also get the last one too using last()
# ---
#
insurance_df.groupby('sex').first()
# Out:
#         age   bmi  children smoker     region  expenses
# sex
# female   19  27.9         0    yes  southwest  16884.92
# male     18  33.8         1     no  southeast   1725.55

# %%
# Example 3
# ---
# We can group a single column by another column then apply an aggregate function as shown
# ---
#
insurance_df['expenses'].groupby([insurance_df['sex']]).sum()

# Method 2
# ---
# NB: The groupby output will have an index or multi-index on rows corresponding
# to our chosen grouping variables. To avoid setting this index,
# we pass “as_index = False” to the groupby operation
# ---
# insurance_df.groupby('sex', as_index = False)['expenses'].sum()
# Out:
# sex
# female    8321061.23
# male      9434763.96
# Name: expenses, dtype: float64

# %%
# Example 4
# ---
# We can group the region column by another column i.e. bmi then apply an aggregate function
# as shown
# ---
#
insurance_df['bmi'].groupby([insurance_df['region']]).mean()

# Method 2
# ---
# insurance_df.groupby('region', as_index = False)['bmi'].mean()
# Out:
# region
# northeast    29.176235
# northwest    29.201846
# southeast    33.359341
# southwest    30.596615
# Name: bmi, dtype: float64

# %%
# Example 5
# ---
# We can create a summary statistical table as shown below
# ---
insurance_df['expenses'].groupby([insurance_df['region']]).describe()

# Method 2
# ---
# insurance_df.groupby('region', as_index = False)['expenses'].describe()
# Out:
#            count          mean           std      min        25%        50%  \
# region
# northeast  324.0  13406.384691  11255.802916  1694.80  5194.3225  10057.655
# northwest  325.0  12417.575169  11072.276880  1621.34  4719.7400   8965.800
# southeast  364.0  14735.411538  13971.098797  1121.87  4440.8850   9294.130
# southwest  325.0  12346.937908  11557.179033  1241.57  4751.0700   8798.590
#
#                   75%       max
# region
# northeast  16687.3650  58571.07
# northwest  14711.7400  60021.40
# southeast  19526.2875  63770.43
# southwest  13462.5200  52590.83

# %%
# Example 6
# ---
# Further seeing how we can group a column by another column as shown
#
insurance_df['children'].groupby([insurance_df['region']]).sum()

# Method 2
# ---
#
# insurance_df.groupby('region', as_index = False)['children'].sum()
# Out:
# region
# northeast    339
# northwest    373
# southeast    382
# southwest    371
# Name: children, dtype: int64

# %%
# Example 7
# ---
# Applying multiple aggregate functions after grouping a column by another column
# ---
#
insurance_df['expenses'].groupby([insurance_df['region']]).agg([min, max, sum])

# Method 2
insurance_df.groupby(['region'], as_index = False).agg({'expenses': [min, max, sum] })
# Out:
#       region expenses
#                   min       max         sum
# 0  northeast  1694.80  58571.07  4343668.64
# 1  northwest  1621.34  60021.40  4035711.93
# 2  southeast  1121.87  63770.43  5363689.80
# 3  southwest  1241.57  52590.83  4012754.82

# %%
# Example 8
# ---
# We can also apply multiple aggregate functions after grouping a column by another column
# ---
#
insurance_df.groupby(['region', 'sex'], as_index = False).agg({'expenses': [min, max, sum] })
# Out:
#       region     sex expenses
#                           min       max         sum
# 0  northeast  female  2196.47  58571.07  2085465.70
# 1  northeast    male  1694.80  48549.18  2258202.94
# 2  northwest  female  2117.34  55135.40  2046698.72
# 3  northwest    male  1621.34  60021.40  1989013.21
# 4  southeast  female  1607.51  63770.43  2362442.12
# 5  southeast    male  1121.87  62592.87  3001247.68
# 6  southwest  female  1727.79  48824.45  1826454.69
# 7  southwest    male  1241.57  52590.83  2186300.13

# %%
# Example 9
# ---
# Grouping by of multiple columns and then applying an aggregate function
# ---
#
insurance_df['expenses'].groupby([insurance_df['region'], insurance_df['sex']]).sum()

# Method 2
# ---
# insurance_df.groupby(['region', 'sex'], as_index = False)['expenses'].sum()

# Method 3
# ---
# insurance_df.groupby(['region', 'sex']).agg({'expenses': ['sum']})
# Out:
# region     sex
# northeast  female    2085465.70
#            male      2258202.94
# northwest  female    2046698.72
#            male      1989013.21
# southeast  female    2362442.12
#            male      3001247.68
# southwest  female    1826454.69
#            male      2186300.13
# Name: expenses, dtype: float64

# %% [markdown]
# ### <font color="green">Challenges</font>

# %%
# Let's load and preview the dataset that we will use for the given challenges.
# ---
# The dataset contains customer invoice data.
# ---
# Dataset url = https://bit.ly/SuperMarketSalesDB
# ---
#

url = "https://bit.ly/SuperMarketSalesDB"
sales_df = pd.read_csv(url)

sales_df.rename(columns = {
      'Invoice ID':"ID",
      'Customer type': "CustomerType",
      'Product line': "ProductLine",
      'Unit price': "UnitPrice",
      'Tax 5%': "Tax",
      'gross margin percentage': "GrossMargin%",
      'gross income': "GrossIncome",
}, inplace= True)
sales_df.set_index("ID", inplace= True)
sales_df.head()
# Out:
#             Branch       City CustomerType  Gender             ProductLine  \
# ID
# 750-67-8428      A     Yangon       Member  Female       Health and beauty
# 226-31-3081      C  Naypyitaw       Normal  Female  Electronic accessories
# 631-41-3108      A     Yangon       Normal    Male      Home and lifestyle
# 123-19-1176      A     Yangon       Member    Male       Health and beauty
# 373-73-7910      A     Yangon       Normal    Male       Sports and travel
#
#              UnitPrice  Quantity      Tax     Total       Date   Time  \
# ID
# 750-67-8428      74.69         7  26.1415  548.9715   1/5/2019  13:08
# 226-31-3081      15.28         5   3.8200   80.2200   3/8/2019  10:29
# 631-41-3108      46.33         7  16.2155  340.5255   3/3/2019  13:23
# 123-19-1176      58.22         8  23.2880  489.0480  1/27/2019  20:33
# 373-73-7910      86.31         7  30.2085  634.3785   2/8/2019  10:37
#
#                  Payment    cogs  GrossMargin%  GrossIncome  Rating
# ID
# 750-67-8428      Ewallet  522.83      4.761905      26.1415     9.1
# 226-31-3081         Cash   76.40      4.761905       3.8200     9.6
# 631-41-3108  Credit card  324.31      4.761905      16.2155     7.4
# 123-19-1176      Ewallet  465.76      4.761905      23.2880     8.4
# 373-73-7910      Ewallet  604.17      4.761905      30.2085     5.3

# %%
# Challenge 1
# ---
# Question: What was the average tax per city?
# ---
# OUR CODE GOES BELOW
#

sales_df.groupby("City")["Tax"].mean()
# Out:
# City
# Mandalay     15.232024
# Naypyitaw    16.052367
# Yangon       14.874001
# Name: Tax, dtype: float64

# %%
# Challenge 2
# ---
# Question: How much did female members from the city of Yagon spend?
# ---
# OUR CODE GOES BELOW
#

sales_df[(sales_df["City"] == "Yagon") & (sales_df["Gender"] == "Female")]
# Out:
# Empty DataFrame
# Columns: [Branch, City, CustomerType, Gender, ProductLine, UnitPrice, Quantity, Tax, Total, Date, Time, Payment, cogs, GrossMargin%, GrossIncome, Rating]
# Index: []

# %%
# Challenge 3
# ---
# Question: How much was spent across all cities?
# ---
# OUR CODE GOES BELOW
#

per_city = sales_df.groupby("City")["cogs"].sum()
per_city.sum()
# Out:
# 307587.38

# %%
# Challenge 4
# ---
# Question: What was the sum of goods sold across all branches?
# ---
# OUR CODE GOES BELOW
#

per_branch = sales_df.groupby("Branch")["cogs"].sum()
total_cogs = per_branch.sum()
per_branch
# Out:
# Branch
# A    101143.21
# B    101140.64
# C    105303.53
# Name: cogs, dtype: float64

# %%
# Challenge 5
# ---
# Question: Which branches collected the most amount of money?
# ---
# OUR CODE GOES BELOW
#

per_branch.sort_values(ascending=0)
# Out:
# Branch
# C    105303.53
# A    101143.21
# B    101140.64
# Name: cogs, dtype: float64

# %%
# Challenge 6
# ---
# Question: Which were the top rated branches?
# ---
# OUR CODE GOES BELOW
#

rating_per_branch = sales_df.groupby("Branch")["Rating"].mean()
rating_per_branch.sort_values(ascending = 0)
# Out:
# Branch
# C    7.072866
# A    7.027059
# B    6.818072
# Name: Rating, dtype: float64

# %%
# Challenge 7
# ---
# Question: Make a comparison between non-members who made cash payments and credit card payments.
# ---
# OUR CODE GOES BELOW
#

# 2 customer Types - Member and Normal
customer_types = list(sales_df["CustomerType"].unique())
# print("Customer Types: ", customer_types, end="\n\n")


# Comparison Cliteria - Total, Rating
non_members_df = sales_df.query("CustomerType == 'Normal' ")
non_members_df = non_members_df[["Payment", "Rating", "Total"]]
# print(non_members_df.head(), end="\n\n")

credit_n_cash_df = non_members_df.query("Payment == 'Cash' or Payment == 'Credit card'")
credit_n_cash_df.groupby("Payment").agg([len, min, np.mean, max])
# Out:
#             Rating                      Total
#                len  min      mean   max   len      min        mean      max
# Payment
# Cash           176  4.1  7.109659   9.9   176  16.1070  326.963378  1003.59
# Credit card    139  4.0  6.907914  10.0   139  12.6945  309.320860  1039.29

# %%
# Challenge 8
# ---
# Question: Show the products line that sold the most indicating the rating.
# ---
# OUR CODE GOES BELOW
#
print("Product Lines (sum-Quantity) (Avg-Rating) (Total Revenue- Sum)")
sales_df.groupby("ProductLine").agg({"Quantity": sum, "Rating": np.mean, "Total": sum}).sort_values("Quantity", ascending=0)
# Out:
# Product Lines (sum-Quantity) (Avg-Rating) (Total Revenue- Sum)
#                         Quantity    Rating       Total
# ProductLine
# Electronic accessories       971  6.924706  54337.5315
# Food and beverages           952  7.113218  56144.8440
# Sports and travel            920  6.916265  55122.8265
# Home and lifestyle           911  6.837500  53861.9130
# Fashion accessories          902  7.029213  54305.8950
# Health and beauty            854  7.003289  49193.7390

# %% [markdown]
# ## 7. Pivot Tables

# %% [markdown]
# ### Examples

# %%
# Example 1
# ---
# A pivot tables is a summary table and comprises of
# outcomes similar to the group by tables.
# ---
# We will start working with pivot tables by getting one column
# and applying an aggregate function as shown below
# ---
#
pd.pivot_table(insurance_df, index=['region'], aggfunc='mean')
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in array_func(values)
#    1489             try:
# -> 1490                 result = self.grouper._cython_operation(
#    1491                     "aggregate",
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in _cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     958         ngroups = self.ngroups
# --> 959         return cy_op.cython_operation(
#     960             values=values,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     656
# --> 657         return self._cython_op_ndim_compat(
#     658             values,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in _cython_op_ndim_compat(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     496
# --> 497         return self._call_cython_op(
#     498             values,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in _call_cython_op(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     540         out_shape = self._get_output_shape(ngroups, values)
# --> 541         func = self._get_cython_function(self.kind, self.how, values.dtype, is_numeric)
#     542         values = self._get_cython_vals(values)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in _get_cython_function(cls, kind, how, dtype, is_numeric)
#     172                 # raise NotImplementedError here rather than TypeError later
# --> 173                 raise NotImplementedError(
#     174                     f"function is not implemented for this dtype: "
#
# NotImplementedError: function is not implemented for this dtype: [how->mean,dtype->object]
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1691         try:
# -> 1692             x = float(x)
#    1693         except (TypeError, ValueError):
#
# ValueError: could not convert string to float: '......
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1695             try:
# -> 1696                 x = complex(x)
#    1697             except ValueError as err:
#
# ValueError: complex() arg is a malformed string
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-e9aa91bbf6bb> in <cell line: 10>()
#       8 # ---
#       9 #
# ---> 10 pd.pivot_table(insurance_df, index=['region'], aggfunc='mean')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      95         return table.__finalize__(data, method="pivot_table")
#      96
# ---> 97     table = __internal_pivot_table(
#      98         data,
#      99         values,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/pivot.py in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     165
#     166     grouped = data.groupby(keys, observed=observed, sort=sort)
# --> 167     agged = grouped.agg(aggfunc)
#     168
#     169     if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1267
#    1268         op = GroupByApply(self, func, args, kwargs)
# -> 1269         result = op.agg()
#    1270         if not is_dict_like(func) and result is not None:
#    1271             return result
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in agg(self)
#     158
#     159         if isinstance(arg, str):
# --> 160             return self.apply_str()
#     161
#     162         if is_dict_like(arg):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_str(self)
#     494             if "axis" in arg_names:
#     495                 self.kwargs["axis"] = self.axis
# --> 496         return self._try_aggregate_string_function(obj, f, *self.args, **self.kwargs)
#     497
#     498     def apply_multiple(self) -> DataFrame | Series:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in _try_aggregate_string_function(self, obj, arg, *args, **kwargs)
#     563         if f is not None:
#     564             if callable(f):
# --> 565                 return f(*args, **kwargs)
#     566
#     567             # people may try to aggregate on a non-callable attribute
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in mean(self, numeric_only, engine, engine_kwargs)
#    1853             return self._numba_agg_general(sliding_mean, engine_kwargs)
#    1854         else:
# -> 1855             result = self._cython_agg_general(
#    1856                 "mean",
#    1857                 alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1505             return result
#    1506
# -> 1507         new_mgr = data.grouped_reduce(array_func)
#    1508         res = self._wrap_agged_manager(new_mgr)
#    1509         out = self._wrap_aggregated_output(res)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in grouped_reduce(self, func)
#    1501                 #  while others do not.
#    1502                 for sb in blk._split():
# -> 1503                     applied = sb.apply(func)
#    1504                     result_blocks = extend_blocks(applied, result_blocks)
#    1505             else:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/blocks.py in apply(self, func, **kwargs)
#     327         one
#     328         """
# --> 329         result = func(self.values, **kwargs)
#     330
#     331         return self._split_op_result(result)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in array_func(values)
#    1501                 # try to python agg
#    1502                 # TODO: shouldn't min_count matter?
# -> 1503                 result = self._agg_py_fallback(values, ndim=data.ndim, alt=alt)
#    1504
#    1505             return result
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in _agg_py_fallback(self, values, ndim, alt)
#    1455         #  should always be preserved by the implemented aggregations
#    1456         # TODO: Is this exactly right; see WrappedCythonOp get_result_dtype?
# -> 1457         res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1458
#    1459         if isinstance(values, Categorical):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func, preserve_dtype)
#     992             preserve_dtype = True
#     993
# --> 994         result = self._aggregate_series_pure_python(obj, func)
#     995
#     996         npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in _aggregate_series_pure_python(self, obj, func)
#    1013
#    1014         for i, group in enumerate(splitter):
# -> 1015             res = func(group)
#    1016             res = libreduction.extract_result(res)
#    1017
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in <lambda>(x)
#    1855             result = self._cython_agg_general(
#    1856                 "mean",
# -> 1857                 alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    1858                 numeric_only=numeric_only,
#    1859             )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   11554             **kwargs,
#   11555         ):
# > 11556             return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11557
#   11558         setattr(cls, "mean", mean)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   11199         **kwargs,
#   11200     ) -> Series | float:
# > 11201         return self._stat_function(
#   11202             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11203         )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11156         validate_bool_kwarg(skipna, "skipna", none_allowed=False)
#   11157
# > 11158         return self._reduce(
#   11159             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11160         )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4668                 )
#    4669             with np.errstate(all="ignore"):
# -> 4670                 return op(delegate, skipna=skipna, **kwds)
#    4671
#    4672     def _reindex_indexer(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      94             try:
#      95                 with np.errstate(invalid="ignore"):
# ---> 96                     return f(*args, **kwargs)
#      97             except ValueError as e:
#      98                 # we want to transform an object array
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     156                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157             else:
# --> 158                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     159
#     160             return result
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in new_func(values, axis, skipna, mask, **kwargs)
#     419             mask = isna(values)
#     420
# --> 421         result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     422
#     423         if datetimelike:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in nanmean(values, axis, skipna, mask)
#     725
#     726     count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 727     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     728
#     729     if axis is not None and getattr(the_sum, "ndim", False):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1697             except ValueError as err:
#    1698                 # e.g. "foo"
# -> 1699                 raise TypeError(f"Could not convert {x} to numeric") from err
#    1700     return x
#    1701
#
# TypeError: Could not convert ......

# %%
# Example 2
# ---
# Getting the first entry for each gender
# NB: You can get the last one too using last().
# In addition, note the that the columns have been arranged alphabetically.
# ---
#
pd.pivot_table(insurance_df, index=['sex'], aggfunc='first')
# Out:
#         age   bmi  children  expenses     region smoker
# sex
# female   19  27.9         0  16884.92  southwest    yes
# male     18  33.8         1   1725.55  southeast     no

# %%
# Example 3
# ---
# We can group a single column by another column then apply an aggregate function as shown
# ---
# We will use numpy to compute the mean
#
pd.pivot_table(insurance_df, index=['sex'], aggfunc={'expenses': np.mean})
# Out:
#             expenses
# sex
# female  12569.578897
# male    13956.751420

# %%
# Example 4
# ---
# Grouping region by another column i.e. bmi, applying an aggregate function
# ---
#
pd.pivot_table(insurance_df, index=['region'], aggfunc={'bmi': np.mean})
# Out:
#                  bmi
# region
# northeast  29.176235
# northwest  29.201846
# southeast  33.359341
# southwest  30.596615

# %%
# Example 5
# ---
# Using a pivote table, we can also create a summary statistical table as shown below
# ---

pd.pivot_table(insurance_df, index=['region'], aggfunc={'expenses': 'describe'})
# Out:
#             expenses                                                        \
#                  25%        50%         75%  count       max          mean
# region
# northeast  5194.3225  10057.655  16687.3650  324.0  58571.07  13406.384691
# northwest  4719.7400   8965.800  14711.7400  325.0  60021.40  12417.575169
# southeast  4440.8850   9294.130  19526.2875  364.0  63770.43  14735.411538
# southwest  4751.0700   8798.590  13462.5200  325.0  52590.83  12346.937908
#
#
#                min           std
# region
# northeast  1694.80  11255.802916
# northwest  1621.34  11072.276880
# southeast  1121.87  13971.098797
# southwest  1241.57  11557.179033

# %%
# Example 6
# ---
# Getting the no. of children in each region
# ---
pd.pivot_table(insurance_df, index=['region'], aggfunc={'children': sum})
# Out:
#            children
# region
# northeast       339
# northwest       373
# southeast       382
# southwest       371

# %%
# Example 6
# ---
# Applying multiple aggregate functions to a group
# ---
#
pd.pivot_table(insurance_df, index=['region', 'sex'], aggfunc={'expenses': [min, max, sum]})
# Out:
#                   expenses
#                        max      min         sum
# region    sex
# northeast female  58571.07  2196.47  2085465.70
#           male    48549.18  1694.80  2258202.94
# northwest female  55135.40  2117.34  2046698.72
#           male    60021.40  1621.34  1989013.21
# southeast female  63770.43  1607.51  2362442.12
#           male    62592.87  1121.87  3001247.68
# southwest female  48824.45  1727.79  1826454.69
#           male    52590.83  1241.57  2186300.13

# %%
# Example 7
# ---
# Applying multiple aggregate functions to a group
# ---
#
pd.pivot_table(insurance_df, index=['region', 'sex'], aggfunc={'expenses': sum})
# Out:
#                     expenses
# region    sex
# northeast female  2085465.70
#           male    2258202.94
# northwest female  2046698.72
#           male    1989013.21
# southeast female  2362442.12
#           male    3001247.68
# southwest female  1826454.69
#           male    2186300.13

# %% [markdown]
# ### <font color="green">Challenges</font>

# %% [markdown]
# The challenges in this section will be same as the ones group by challenges. Compare your solutions with the ones you got in the previous section.

# %%
# You will use the supermarket dataset you previously used.
# ---
# The dataset contains customer invoice data.
# ---
# Dataset url = https://bit.ly/SuperMarketSalesDB
# ---
#

sales_df.head()
# Out:
#             Branch       City CustomerType  Gender             ProductLine  \
# ID
# 750-67-8428      A     Yangon       Member  Female       Health and beauty
# 226-31-3081      C  Naypyitaw       Normal  Female  Electronic accessories
# 631-41-3108      A     Yangon       Normal    Male      Home and lifestyle
# 123-19-1176      A     Yangon       Member    Male       Health and beauty
# 373-73-7910      A     Yangon       Normal    Male       Sports and travel
#
#              UnitPrice  Quantity      Tax     Total       Date   Time  \
# ID
# 750-67-8428      74.69         7  26.1415  548.9715   1/5/2019  13:08
# 226-31-3081      15.28         5   3.8200   80.2200   3/8/2019  10:29
# 631-41-3108      46.33         7  16.2155  340.5255   3/3/2019  13:23
# 123-19-1176      58.22         8  23.2880  489.0480  1/27/2019  20:33
# 373-73-7910      86.31         7  30.2085  634.3785   2/8/2019  10:37
#
#                  Payment    cogs  GrossMargin%  GrossIncome  Rating
# ID
# 750-67-8428      Ewallet  522.83      4.761905      26.1415     9.1
# 226-31-3081         Cash   76.40      4.761905       3.8200     9.6
# 631-41-3108  Credit card  324.31      4.761905      16.2155     7.4
# 123-19-1176      Ewallet  465.76      4.761905      23.2880     8.4
# 373-73-7910      Ewallet  604.17      4.761905      30.2085     5.3

# %%
# Challenge 1
# ---
# Question: What was the average tax per city?
# ---
# OUR CODE GOES BELOW
#

pd.pivot_table(sales_df, index=["City"], aggfunc={"Tax": np.mean})
# Out:
#                  Tax
# City
# Mandalay   15.232024
# Naypyitaw  16.052367
# Yangon     14.874001

# %%
# Challenge 2
# ---
# Question: How much did female members from the city of Yagon spend?
# ---
# OUR CODE GOES BELOW
#

pd.pivot_table(sales_df, index=["Gender", "City"], aggfunc={"Total": sum}).loc["Female"].loc["Yangon"]
# Out:
# Total    53269.167
# Name: Yangon, dtype: float64

# %%
# Challenge 3
# ---
# Question: How much was spent across all cities?
# ---
# OUR CODE GOES BELOW
#
pd.pivot_table(sales_df, index=["City"], aggfunc={"Total": sum}).sort_values("Total", ascending=0)
# Out:
#                  Total
# City
# Naypyitaw  110568.7065
# Yangon     106200.3705
# Mandalay   106197.6720

# %%
# Challenge 4
# ---
# Question: What was the sum of goods sold across all branches?
# ---
# OUR CODE GOES BELOW
#

pd.pivot_table(sales_df, index=["Branch"], aggfunc={"cogs":sum}).sort_values("cogs", ascending=False)
# Out:
#              cogs
# Branch
# C       105303.53
# A       101143.21
# B       101140.64

# %%
# Challenge 5
# ---
# Question: Which branches collected the most amount of money?
# ---
# OUR CODE GOES BELOW
#

pd.pivot_table(sales_df, index=["Branch"], aggfunc={"Total":sum}).sort_values("Total", ascending=False).head()
# Out:
#               Total
# Branch
# C       110568.7065
# A       106200.3705
# B       106197.6720

# %%
# Challenge 6
# ---
# Question: Which were the top rated branches?
# ---
# OUR CODE GOES BELOW
#

pd.pivot_table(sales_df, index=["Branch"], aggfunc={"Rating": np.mean}).sort_values("Rating", ascending= False).head()
# Out:
#           Rating
# Branch
# C       7.072866
# A       7.027059
# B       6.818072

# %%
# Challenge 7
# ---
# Question: Make a comparison between non-members who made cash payments and credit card payments.
# ---
# OUR CODE GOES BELOW
#

pd.pivot_table(sales_df, )

# %%
# Challenge 8
# ---
# Question: Show the products line that sold the most indicating the rating.
# ---
# OUR CODE GOES BELOW
#

pd.pivot_table(sales_df, index=["ProductLine"], aggfunc={ "Rating": np.mean, "Total":sum}).sort_values("Total", ascending= False)[["Total", "Rating"]]
# Out:
#                              Total    Rating
# ProductLine
# Food and beverages      56144.8440  7.113218
# Sports and travel       55122.8265  6.916265
# Electronic accessories  54337.5315  6.924706
# Fashion accessories     54305.8950  7.029213
# Home and lifestyle      53861.9130  6.837500
# Health and beauty       49193.7390  7.003289
